# %%
import os
from rapidocr_onnxruntime import RapidOCR
# from rapidocr_paddle import RapidOCR
engine = RapidOCR(det_use_cuda=True, cls_use_cuda=True, rec_use_cuda=True)
img_ful_path = r"E:\explore\CLI2P\dataset\001T110027850\001T110027850.jpg-0enhance-0.jpg"
engine(img_ful_path)
# Out:
# 2024-10-10 15:33:34,677 - OrtInferSession - WARNING: CUDAExecutionProvider is not avaiable for current env, the inference part is automatically shifted to be executed under CPUExecutionProvider.
# 2024-10-10 15:33:34,718 - OrtInferSession - WARNING: CUDAExecutionProvider is not avaiable for current env, the inference part is automatically shifted to be executed under CPUExecutionProvider.
# 2024-10-10 15:33:34,858 - OrtInferSession - WARNING: CUDAExecutionProvider is not avaiable for current env, the inference part is automatically shifted to be executed under CPUExecutionProvider.
# ([[[[124.0, 12.0], [641.0, 5.0], [643.0, 115.0], [125.0, 123.0]],
#    '老人与海',
#    0.99894243],
#   [[[686.0, 16.0], [772.0, 16.0], [772.0, 41.0], [686.0, 41.0]],
#    'THE',
#    0.99667495],
#   [[[799.0, 17.0], [882.0, 17.0], [882.0, 39.0], [799.0, 39.0]],
#    'OLD',
#    0.9850397],
#   [[[913.0, 18.0], [995.0, 18.0], [995.0, 38.0], [913.0, 38.0]],
#    'MAN',
#    0.59445],
#   [[[685.0, 47.0], [773.0, 46.0], [773.0, 72.0], [685.0, 74.0]],
#    'AND',
#    0.995182],
#   [[[1090.0, 40.0], [1131.0, 40.0], [1131.0, 79.0], [1090.0, 79.0]],
#    '美',
#    0.9997305],
#   [[[1562.0, 45.0], [2091.0, 26.0], [2093.0, 78.0], [1564.0, 97.0]],
#    'H319.4:1712.45/',
#    0.9894315],
#   [[[687.0, 76.0], [880.0, 76.0], [880.0, 101.0], [687.0, 102.0]],
#    'THESEA',
#    0.99528784]],
#  [1.0048101000000145, 0.010423898696899414, 0.5221891403198242])

# %%
def get_use_content_from_ocr(reses):
    res_text = ''
    for res in reses:
        if len(res[1]) > 0:
            res_text += res[1]
            res_text += ' '
    return res_text.strip()

# %%
# img_path = r'E:\explore\CLI2P\dataset\001T110027850\001T110027850.jpg-0enhance-0.jpg'
# res, _ = engine(img_path)
# print(f'res:{res}')

# %%
# get_use_content_from_ocr(res)

# %%
dataset_path = r'./datasets'
# from tqdm import tqdm as notebook_tqdm
collect_text_len = []
collect_invaild_img_l = []

for root, dirs, files in os.walk(dataset_path):
    # print(f'root:{root}')
    # print(f'dir:{dir}')
    # print(f"file:{file}")
    for file in files:
        if file.endswith(('.jpg','.png')):
            
            img_ful_path = os.path.join(root, file)
            txt_ful_path = os.path.splitext(img_ful_path)[0] + '.txt'
            # print(img_ful_path)
            # print(txt_ful_path)
            res, _ = engine(img_ful_path)
            # print(f'res:{res}')
            if res is not None:
                res_str = get_use_content_from_ocr(res)
                # print(res_str)
                # print(f'text-len:{len(res_str)}')
                collect_text_len.append(len(res_str))
                with open(txt_ful_path, 'w', encoding='utf-8') as file:
                    file.write(res_str)
            else:
                collect_invaild_img_l.append(img_ful_path)

# %%
len(collect_invaild_img_l)
# Out:
# 0

# %%
# 删除 无效列表中的图像数据， 顺便将对应的txt标签数据也删除、
import shutil
for i in collect_invaild_img_l:
    img_ful_path = i
    txt_ful_path = os.path.splitext(img_ful_path)[0] + '.txt'
    # print('='*10)
    # print(f'img_ful_path:{img_ful_path}')
    # print(f'txt_ful_path:{txt_ful_path}')
    os.remove(img_ful_path)
    if os.path.exists(txt_ful_path):
        os.remove(txt_ful_path)

# %%
collect_invaild_img_l[:4]
# Out:
# []

# %%
max(collect_text_len)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 max(collect_text_len)
#
# ValueError: max() arg is an empty sequence

# %%
sum(collect_text_len)/len(collect_text_len)
# Out:
# 31.768123393316195

# %%
import statistics
median = statistics.median(collect_text_len)
print(median)
# Out:
# 29

# %%
# TODO: 划分数据集
import random


def is_empty_dir(directory):
    return os.path.isdir(directory) and not os.listdir(directory)

dataset_path = r'./datasets'

prepare_dataset_path = r'./datasets_book_spine'
shutil.rmtree(prepare_dataset_path)

train_dir = os.path.join(prepare_dataset_path, 'train')
val_dir = os.path.join(prepare_dataset_path, 'val')
test_dir = os.path.join(prepare_dataset_path, 'test')
# -- 训练集 --
if not os.path.exists(train_dir):
    os.makedirs(train_dir)
# -- 验证集 --
if not os.path.exists(val_dir):
    os.makedirs(val_dir)
# -- 测试集 --
if not os.path.exists(test_dir):
    os.makedirs(test_dir)
    
for dir_name in os.listdir(dataset_path):
    if dir_name not in ['train','val','test']:
        src_dir_path = os.path.join(dataset_path, dir_name)
        
        random_number = random.random()
        print(f'random_number:{random_number}')
        if is_empty_dir(src_dir_path):
            continue
        if random_number < 0.1: # 测试集
            dst_dir_path = os.path.join(test_dir, dir_name)
        elif random_number < 0.3: # 验证集
            dst_dir_path = os.path.join(val_dir, dir_name)
        else: # 训练集
            dst_dir_path = os.path.join(train_dir, dir_name)
        shutil.copytree(src_dir_path, dst_dir_path)
# Out:
# random_number:0.00338631209907303
# random_number:0.8096416542042781
# random_number:0.15890804827201688
# random_number:0.7400572819307388
# random_number:0.2680067968904828
# random_number:0.661637847874989
# random_number:0.98854231333756
# random_number:0.5843774394230927
# random_number:0.8317079039009898
# random_number:0.5966321988843359
# random_number:0.48482172355071673
# random_number:0.8707000643634275
# random_number:0.5897773802527239
# random_number:0.057691278949588254
# random_number:0.39509214247554825
# random_number:0.28925261462726504
# random_number:0.8536201060091246
# random_number:0.40340133279157153
# random_number:0.49667158086247265
# random_number:0.5677174022648342
# random_number:0.4119868971367743
# random_number:0.9143167929642478
# random_number:0.972266495397507
# random_number:0.5963007489650818
# random_number:0.9770174647297855
# random_number:0.12320876588537244
# random_number:0.9407973837368501
# random_number:0.23340675589985682
# random_number:0.04517697808563281
# random_number:0.2817640963564515
# random_number:0.042572745950912316
# random_number:0.4640815441393711
# random_number:0.20750488483543061
# random_number:0.43022057254684465
# random_number:0.44034693164704
# random_number:0.5107362247162974
# random_number:0.9383779270881932
# random_number:0.7821874307536552
# random_number:0.5366954194797448
# random_number:0.7196297057199087
# random_number:0.10389127025423239
# random_number:0.7072046150156335
# random_number:0.45739493345312066
# random_number:0.09775791939485201
# random_number:0.29206460212224283
# random_number:0.8083471504077113
# random_number:0.27086575786736955
# random_number:0.782673608153282
# random_number:0.9669391200739788
# random_number:0.4520965375796977
# random_number:0.30733237078727715
# random_number:0.7553047881240951
# random_number:0.6317301639975929
# random_number:0.8995003139115825
# random_number:0.08328445726304312
# random_number:0.8472452493871225
# random_number:0.7177966952961015
# random_number:0.7206604182652656
# random_number:0.9680090545356681
# random_number:0.7805824535556916
# random_number:0.028341483579537363
# random_number:0.8785122051993233
# random_number:0.5297686599313595
# random_number:0.7416646296670817
# random_number:0.7644732619786939
# random_number:0.8465364671020875
# random_number:0.5210276427221927
# random_number:0.8232727920604055
# random_number:0.40392049213097214
# random_number:0.751582507415095
# random_number:0.48202742966134826
# random_number:0.6082727638794021
# random_number:0.11832627510892235
# random_number:0.6522216860718362
# random_number:0.6866139351265074
# random_number:0.38389047506987395
# random_number:0.43051857385207615
# random_number:0.11622450229141001
# random_number:0.5740926884580831
# random_number:0.48908883698503824
# random_number:0.5445536782333515
# random_number:0.5002138165692152
# random_number:0.9949789579623818
# random_number:0.08242214955004656
# random_number:0.8783070798163687
# random_number:0.8517789662206371
# random_number:0.5616723255630538
# random_number:0.43260604488223975
# random_number:0.08936297406543292
# random_number:0.48583612393550724
# random_number:0.8090480313940265
# random_number:0.4012183184516622
# random_number:0.3277026665542665
# random_number:0.11933902035676824
# random_number:0.3366686691697839
# random_number:0.7899020199990069
# random_number:0.4272630222130738
# random_number:0.9371998577607563
# random_number:0.6014400109467746
# random_number:0.41930089491760825
# random_number:0.14248640723033734
# random_number:0.46981330988896175
# random_number:0.4923229744524832
# random_number:0.7404091845907586
# random_number:0.04582107969722604
# random_number:0.3642714309061017
# random_number:0.4104857295833997
# random_number:0.48017851390470545
# random_number:0.03862157093834406
# random_number:0.30178428785328937
# random_number:0.37375815896544096
# random_number:0.07462795213364493
# random_number:0.8944972642003342
# random_number:0.234543714048293
# random_number:0.400799461569042
# random_number:0.7783205517950694
# random_number:0.4836965175863528
# random_number:0.24673630831012117
# random_number:0.8198476065354817
# random_number:0.7452969005106359
# random_number:0.3711938196615425
# random_number:0.2900009706279739
# random_number:0.4789857557760351
# random_number:0.4393251989912611
# random_number:0.9626277521746369
# random_number:0.02582464366592996
# random_number:0.5400276947326166
# random_number:0.7263581108690047
# random_number:0.9879134289774589
# random_number:0.30586454946986796
# random_number:0.29643560501274613
# random_number:0.33764447986068136
# random_number:0.8728115161536547
# random_number:0.5035335779246835
# random_number:0.6716394194729284
# random_number:0.12095018506863131
# random_number:0.7646755027959665
# random_number:0.38949565433523026
# random_number:0.02947375981424094
# random_number:0.9134291986047565
# random_number:0.5812892710638333
# random_number:0.5700620796613213
# random_number:0.43404050503318703
# random_number:0.9075121123553815
# random_number:0.24360235428931243
# random_number:0.5231444110748114
# random_number:0.16669768372338867
# random_number:0.9021107428726101
# random_number:0.7470746592132855
# random_number:0.2733405431175512
# random_number:0.8258650438981415
# random_number:0.20467687998667505
# random_number:0.8540744093680824
# random_number:0.7457011228526879
# random_number:0.5395472638638313
# random_number:0.5048487418737121
# random_number:0.9919239972119719
# random_number:0.8732185421738718
# random_number:0.9527375157381247
# random_number:0.30592628966528557
# random_number:0.5983776089892402
# random_number:0.018418992094450082
# random_number:0.2616100363671
# random_number:0.4084477005638343
# random_number:0.518856515242309
# random_number:0.540422861897298
# random_number:0.3994026251479035
# random_number:0.652483564971459
# random_number:0.261697151443548
# random_number:0.45504537460472083
# random_number:0.8750880044037666
# random_number:0.7925054677745712
# random_number:0.5435332003800851
# random_number:0.1835679422860883
# random_number:0.5528051374077637
# random_number:0.2312537794725732
# random_number:0.9396042740957617
# random_number:0.1309562858396115
# random_number:0.7989141778539592
# random_number:0.05692439758728185
# random_number:0.7774291265434212
# random_number:0.33153669541414943
# random_number:0.42873683655859707
# random_number:0.05334832446604654
# random_number:0.9215616497815737
# random_number:0.5851807289979462
# random_number:0.8003957581685879
# random_number:0.034449961988179956
# random_number:0.5611516334833038
# random_number:0.16660046924884309
# random_number:0.32179558527783214
# random_number:0.0024286855721894485
# random_number:0.6834491752351765
# random_number:0.8269515302610694
# random_number:0.4232017539154951
# random_number:0.8944022858522068
# random_number:0.010173394365283861
# random_number:0.37942599898101703
# random_number:0.20993541458082787
# random_number:0.15041680673105207
# random_number:0.10716535523641124
# random_number:0.4731276359673964
# random_number:0.9054957622746904
# random_number:0.775608790335867
# random_number:0.18841656134931384
# random_number:0.07037428532124868
# random_number:0.7596187187845688
# random_number:0.24178042113474496
# random_number:0.46460301930755543
# random_number:0.529451124551475
# random_number:0.7385514823380185
# random_number:0.7522356581331663
# random_number:0.35404349365028087
# random_number:0.12407600057398005
# random_number:0.3043030735221325
# random_number:0.8452841281020737
# random_number:0.4228198114034748
# random_number:0.7926248707329576
# random_number:0.38786824011779863
# random_number:0.4788163042429373
# random_number:0.44557416583889187
# random_number:0.6062839600801935
# random_number:0.9298404034760557
# random_number:0.34441067530016567
# random_number:0.2100728073917244
# random_number:0.4963127600634699
# random_number:0.5323977149091061
# random_number:0.3365805010240356
# random_number:0.6424611508187069
# random_number:0.22296251171768366
# random_number:0.9861033149498798
# random_number:0.28750249054538435
# random_number:0.9514971270659346
# random_number:0.3822197499901038
# random_number:0.34813788836738546
# random_number:0.9691249778496512
# random_number:0.6694115353174294
# random_number:0.27860763132267574
# random_number:0.3021342564251671
# random_number:0.07870448073183556
# random_number:0.47448645933019995
# random_number:0.7848245461021434
# random_number:0.952663049924419
# random_number:0.2869557293469144
# random_number:0.8793485521635219
# random_number:0.8625072087237925
# random_number:0.05407257020641798
# random_number:0.8530856416820374
# random_number:0.20386534322213778
# random_number:0.043026082765963536
# random_number:0.5298469978072138
# random_number:0.9533689744196395
# random_number:0.6782652828576771
# random_number:0.6573269706570003
# random_number:0.4061612989761647
# random_number:0.06060308222837241
# random_number:0.7197925019133328
# random_number:0.04661286560308642
# random_number:0.469021191237713
# random_number:0.5123273659769425
# random_number:0.4916495948830941
# random_number:0.24568276462475225
# random_number:0.5183325720315317
# random_number:0.8706164552455978
# random_number:0.4256423946984238
# random_number:0.5917613232010517
# random_number:0.6387048666167531
# random_number:0.46662421658112707
# random_number:0.340323209747073
# random_number:0.8260341456272954
# random_number:0.6957430937994612
# random_number:0.022059792360041408
# random_number:0.9562077122065787
# random_number:0.6431492096286101
# random_number:0.10677888738429664
# random_number:0.2042919138709679
# random_number:0.16172019544277239
# random_number:0.8934457284614398
# random_number:0.6484305127628323
# random_number:0.8741283554770833
# random_number:0.49689797540083425
# random_number:0.7082610471409403
# random_number:0.49465943022126735
# random_number:0.8229513559927558
# random_number:0.5352020252091232
# random_number:0.6817684212844627
# random_number:0.750568815154448
# random_number:0.00562407013452193
# random_number:0.4363901119344027
# random_number:0.8056639526501671
# random_number:0.06804069201893659
# random_number:0.6220013040224691
# random_number:0.023576228593200743
# random_number:0.13425505020594697
# random_number:0.4885473986432751
# random_number:0.5752446227362239
# random_number:0.048770288942777795
# random_number:0.18501066169478098
# random_number:0.34948750618907787
# random_number:0.0010792898683031904
# random_number:0.9396677046406416
# random_number:0.6769649228214741
# random_number:0.7865355844138234
# random_number:0.28977741335659557
# random_number:0.2951497551260125
# random_number:0.46606578269463195
# random_number:0.7142590507458283
# random_number:0.5541878513314094
# random_number:0.30784004450226476
# random_number:0.3493840670642947
# random_number:0.13427537949862045
# random_number:0.3786450614571206
# random_number:0.23752300477773247
# random_number:0.8626110297789372
# random_number:0.7185442572328221
# random_number:0.9085714006183391
# random_number:0.07547192005253245
# random_number:0.014092494379912335
# random_number:0.23097639710814277
# random_number:0.8902005822008909
# random_number:0.1236008196807028
# random_number:0.6766608030701695
# random_number:0.6795693828756574
# random_number:0.28826181232035264
# random_number:0.5285047435078382
# random_number:0.6399337941794919
# random_number:0.2091908120446675
# random_number:0.7423936579071353
# random_number:0.11895314027506398
# random_number:0.3637127730895219
# random_number:0.799533012286479
# random_number:0.5913322005105628
# random_number:0.8348032249800837
# random_number:0.5186431755706138
# random_number:0.41842337223191983
# random_number:0.7616696936761863
# random_number:0.09228665067209285
# random_number:0.055064370603946644
# random_number:0.19746400332516
# random_number:0.26767253805646907
# random_number:0.5031717874538377
# random_number:0.38600565981736734
# random_number:0.0897725510013353
# random_number:0.6267174968809983
# random_number:0.3986524493260799
# random_number:0.5384232682000077
# random_number:0.8038573786976226
# random_number:0.8857494799930389
# random_number:0.6705971016863713
# random_number:0.9439880181289652
# random_number:0.3551897667848254
# random_number:0.870441817621189
# random_number:0.8445067281309055
# random_number:0.7530574329126584
# random_number:0.3023906819927036
# random_number:0.03829779493171148
# random_number:0.697877161428484
# random_number:0.1727968531552414
# random_number:0.4896253157855721
# random_number:0.37589297156139956
# random_number:0.993117134413981
# random_number:0.9495433905743793
# random_number:0.6313570552796776
# random_number:0.09843305869114893
# random_number:0.6264152563495465
# random_number:0.5671223885968626
# random_number:0.4571721892936167
# random_number:0.47622418876817774
# random_number:0.5405132161460788
# random_number:0.8684442591897424
# random_number:0.0653863760345218
# random_number:0.20759070053012973
# random_number:0.5889054554367424
# random_number:0.054304197841589796
# random_number:0.6754832367178102
# random_number:0.8205468175628363
# random_number:0.8793996619513568
# random_number:0.28015257069968014
# random_number:0.5187481913143568
# random_number:0.7778387424630833
# random_number:0.27443602662067446
# random_number:0.16300812248819563
# random_number:0.74426666403773
# random_number:0.48875475686913405
# random_number:0.6559417209936039
# random_number:0.5338995239337357
# random_number:0.36600203967149236
# random_number:0.22519068307588452
# random_number:0.997936786614581
# random_number:0.9630744942572658
# random_number:0.24185740787956145
# random_number:0.19497643499115758
# random_number:0.8142058044406338
# random_number:0.9727758636379761
# random_number:0.8836227126927032
# random_number:0.7563321372532255
# random_number:0.9371042502007995
# random_number:0.21750392372779115
# random_number:0.2759109801470484
# random_number:0.6896183767108289
# random_number:0.503811806914603
# random_number:0.106539000648875
# random_number:0.569244319231808
# random_number:0.15725163799547692
# random_number:0.12455579051227439
# random_number:0.5828441485413679
# random_number:0.8327838088812108
# random_number:0.27887475339859447
# random_number:0.7070066416645866
# random_number:0.4827346722547733
# random_number:0.033825479759450494
# random_number:0.6546289957954259
# random_number:0.3864976879000577
# random_number:0.5924736782299167
# random_number:0.6670508298319987
# random_number:0.3164506868570155
# random_number:0.28609531590004855
# random_number:0.5871168378034035
# random_number:0.7088131533608184
# random_number:0.4808826380223049
# random_number:0.3642756127617208
# random_number:0.38792497336592036
# random_number:0.7218424160364473
# random_number:0.16039693521415632
# random_number:0.8580082670597187
# random_number:0.08708178960852075
# random_number:0.7089539051452942
# random_number:0.5044306060995678
# random_number:0.4618630054577205
# random_number:0.5102271484953279
# random_number:0.8288049417795466
# random_number:0.35762411694582286
# random_number:0.44020583640988764
# random_number:0.801812819785567
# random_number:0.49145058738450387
# random_number:0.2035343580787532
# random_number:0.04086633092363645
# random_number:0.8932108422936759
# random_number:0.34791794011823307
# random_number:0.8032748155569722
# random_number:0.11151672356879982
# random_number:0.5503981934450509
# random_number:0.9701635244989447
# random_number:0.3839845869093452
# random_number:0.8177328798558494
# random_number:0.944853988010368
# random_number:0.999116770913175
# random_number:0.33260896315107413
# random_number:0.9513522897201326
# random_number:0.40560815222251023
# random_number:0.03724963523833125
# random_number:0.5643058801749401
# random_number:0.09328874059950498
# random_number:0.40552883620381586
# random_number:0.025847374751020835
# random_number:0.09569304843263471
# random_number:0.12470067031498033
# random_number:0.7390851506439601
# random_number:0.6267807783981449
# random_number:0.8935069067572147
# random_number:0.17807027957413013
# random_number:0.7998850560724646
# random_number:0.3041767808093072
# random_number:0.14101511573253767
# random_number:0.2729838594747228
# random_number:0.4290813184722526
# random_number:0.2023687132060955
# random_number:0.017750782350867134
# random_number:0.9021438098629834
# random_number:0.7085483758281848
# random_number:0.6716824095048175
# random_number:0.4087738102785211
# random_number:0.45948342174860035
# random_number:0.6561736149676242
# random_number:0.03261203935162327
# random_number:0.7248724125541469
# random_number:0.5568605738195617
# random_number:0.9603744731107215
# random_number:0.011776137751977833
# random_number:0.5525407821341001
# random_number:0.9472192492127762
# random_number:0.18459901151059088
# random_number:0.32496811760895983
# random_number:0.9149582116525847
# random_number:0.39682041695021086
# random_number:0.8696426292350186
# random_number:0.885282656162383
# random_number:0.5977054962621565
# random_number:0.4900490147336857
# random_number:0.8344307975033384
# random_number:0.45212635142594193
# random_number:0.16387738012780517
# random_number:0.5351049529153867
# random_number:0.3752819218834874
# random_number:0.4649497868228545
# random_number:0.20233965504700713
# random_number:0.10679618424104598
# random_number:0.24629327190177008
# random_number:0.5111897299793299
# random_number:0.9803024262630308
# random_number:0.48453611567922117
# random_number:0.6310459979423807
# random_number:0.01209755492157305
# random_number:0.05872370702484753
# random_number:0.07777920164569396
# random_number:0.8193050778132221
# random_number:0.8501154201950673
# random_number:0.3422133281244376
# random_number:0.9724012577407463
# random_number:0.48586274461865764
# random_number:0.3334382880116922
# random_number:0.2132285071385831
# random_number:0.7496131774258391
# random_number:0.3155862191774025
# random_number:0.35513196759385524
# random_number:0.32877152153293243
# random_number:0.08238213049714804
# random_number:0.18248140957126424
# random_number:0.11935736114836248
# random_number:0.533076293044523
# random_number:0.09087977044685314
# random_number:0.8102794901171477
# random_number:0.5679080183252805
# random_number:0.45888315180859196
# random_number:0.22109809038313555
# random_number:0.03224285434971719
# random_number:0.5775226422694034
# random_number:0.666898675013256
# random_number:0.7799086269941724
# random_number:0.2618669717026787
# random_number:0.5424199019458152
# random_number:0.8026707111726719
# random_number:0.8902941971180744
# random_number:0.4305352905203994
# random_number:0.6659194317580236
# random_number:0.23959021593527086
# random_number:0.7043381777530847
# random_number:0.9392746900431833
# random_number:0.4993790573956757
# random_number:0.1584247453825003
# random_number:0.226681769525647
# random_number:0.39537251490759073
# random_number:0.1291652383850449
# random_number:0.7339132741014011
# random_number:0.18067603984395963
# random_number:0.7057202456118504
# random_number:0.40279447175097083
# random_number:0.6791584468180997
# random_number:0.5122486587568853
# random_number:0.34657921771901024
# random_number:0.27180136974786506
# random_number:0.6511541838615904
# random_number:0.6235190313879647
# random_number:0.4935253714880853
# random_number:0.9005679700614997
# random_number:0.05604341044955641
# random_number:0.308816365389887
# random_number:0.7556648289837272
# random_number:0.7092630174394312
# random_number:0.08154944222180316
# random_number:0.948017123245844
# random_number:0.7407936394455173
# random_number:0.22187597639071643
# random_number:0.4845740203060511
# random_number:0.03862592366453976
# random_number:0.07734656348509694
# random_number:0.08483171980417281
# random_number:0.5442372347795552
# random_number:0.06811142168636308
# random_number:0.9581389989366326
# random_number:0.9228065623354257
# random_number:0.8817629816085067
# random_number:0.20347950966423367
# random_number:0.9073619202748331
# random_number:0.5133559353337769
# random_number:0.31934568923617657
# random_number:0.26057842335381576
# random_number:0.16368898727958114
# random_number:0.824907583387014
# random_number:0.7215943260031558
# random_number:0.10595975160407067
# random_number:0.12393672631357266
# random_number:0.8620107012819008
# random_number:0.6483507751422075
# random_number:0.7537159626490604
# random_number:0.34772752357381176
# random_number:0.21318929527376917
# random_number:0.20286597828199082
# random_number:0.8892780780545929
# random_number:0.7691326330061813
# random_number:0.13327432888035284
# random_number:0.09860426848640058
# random_number:0.48410098582226846
# random_number:0.7816977071588131
# random_number:0.36305536382628034
# random_number:0.6518179137854179
# random_number:0.08243382636499497
# random_number:0.8395765350468447
# random_number:0.776528233594757
# random_number:0.21892133262355618
# random_number:0.9816447970682142
# random_number:0.7466322594564351
# random_number:0.834625823667168
# random_number:0.9264618983535188
# random_number:0.9867875689066976
# random_number:0.5978962712903211
# random_number:0.8857898689706697
# random_number:0.2701008318409649
# random_number:0.6044636137675006
# random_number:0.776980016546387
# random_number:0.14748938335228745
# random_number:0.20696951588766554
# random_number:0.9962881036212251
# random_number:0.3019646517172738
# random_number:0.16581714492607302
# random_number:0.1572216301241368
# random_number:0.9190151305682488
# random_number:0.4122457737281461
# random_number:0.6317284489651552
# random_number:0.9491509070613927
# random_number:0.8432570372473669
# random_number:0.3518583949777314
# random_number:0.6199864857206182
# random_number:0.4506798278045677
# random_number:0.0488037255718049
# random_number:0.06777207920395145
# random_number:0.46142539902136004
# random_number:0.5402459947542987
# random_number:0.04924260138927161
# random_number:0.2705765880249069
# random_number:0.7867995200281567
# random_number:0.3884367982498155
# random_number:0.35253973098179914
# random_number:0.1673958792282858
# random_number:0.8786528697273253
# random_number:0.7054302993706025
# random_number:0.40332039454668844
# random_number:0.4208819147215691
# random_number:0.8532498418778375
# random_number:0.4215729414227114
# random_number:0.06288878982152268
# random_number:0.9920832217093712
# random_number:0.9794795461994886
# random_number:0.9023293644711923
# random_number:0.840772900389682
# random_number:0.11230328713170223
# random_number:0.5704336616180395
# random_number:0.9275268092350851
# random_number:0.6373532682252889
# random_number:0.03445449660613742
# random_number:0.8700447862509799
# random_number:0.4351262148012697
# random_number:0.4934098349717978
# random_number:0.15161357319728197
# random_number:0.8438773039700046
# random_number:0.07285933450139048
# random_number:0.4812766295083287
# random_number:0.797911164428967
# random_number:0.7167206119748752
# random_number:0.8189663366481954
# random_number:0.532346660431334
# random_number:0.5808600431851297
# random_number:0.2614574840841183
# random_number:0.7209955219156402
# random_number:0.04220386902355866
# random_number:0.5180425448945103
# random_number:0.013552397871031574
# random_number:0.26555847466133975
# random_number:0.009216173366141556
# random_number:0.4011019823973767
# random_number:0.632555507318256
# random_number:0.503436962301599
# random_number:0.09119333896912174
# random_number:0.5276949531015198
# random_number:0.5114526399188595
# random_number:0.7644732566363296
# random_number:0.5783344206602605
# random_number:0.9875422175260266
# random_number:0.4126659175471127
# random_number:0.2098604159190065
# random_number:0.8219230214499829
# random_number:0.949452943958825
# random_number:0.6825316681351485
# random_number:0.4777624461130524
# random_number:0.44569910078751607
# random_number:0.9156045001691732
# random_number:0.5762927041192971
# random_number:0.3627761500161176
# random_number:0.5761256120739768
# random_number:0.8922343869702027
# random_number:0.9167081289601939
# random_number:0.8653785660983271
# random_number:0.36860121573558846
# random_number:0.8034252429837773
# random_number:0.5815628148618937
# random_number:0.31681013658766344
# random_number:0.7547519927145614
# random_number:0.2901953181183582
# random_number:0.7041320178169004
# random_number:0.7296076352551106
# random_number:0.733594303358743
# random_number:0.24790070514365747
# random_number:0.9308701296934625
# random_number:0.8186316589917242
# random_number:0.13175798520329896
# random_number:0.703862217825748
# random_number:0.6876671390883123
# random_number:0.7356090135411505
# random_number:0.8024081336741601
# random_number:0.36241905402096763
# random_number:0.9418858558642742
# random_number:0.23549773748332925
# random_number:0.6988230630009227
# random_number:0.029375525637080013
# random_number:0.6910469561491526
# random_number:0.7770220617554404
# random_number:0.0780593709839239
# random_number:0.029780707495020375
# random_number:0.5965445747702387
# random_number:0.16611968522717946
# random_number:0.752567626652107
# random_number:0.3258183215019491
# random_number:0.03763388991974437
# random_number:0.9279654618803054
# random_number:0.30410210592940956
# random_number:0.4919904298241121
# random_number:0.35939632924596865
# random_number:0.16422540781674022
# random_number:0.8961411445322638
# random_number:0.326315225911214
# random_number:0.4755192272504877
# random_number:0.4503939659623323
# random_number:0.6675843806996858
# random_number:0.14041786921746524
# random_number:0.8899020036113402
# random_number:0.47102889238210677
# random_number:0.4193094056180926
# random_number:0.8626507110438022
# random_number:0.17188077513978695
# random_number:0.8071215813419842
# random_number:0.40071211737017154
# random_number:0.5302233656579236
# random_number:0.12223713456302798
# random_number:0.151341693999137
# random_number:0.6865122324912697
# random_number:0.10446319936233228
# random_number:0.5373515208661728
# random_number:0.7143204157005301
# random_number:0.4047447734999925
# random_number:0.30164752321507493
# random_number:0.009811061788986719
# random_number:0.07614703563389169
# random_number:0.7165748895482316
# random_number:0.1822728172076734
# random_number:0.7304140845961535
# random_number:0.4858186932898453
# random_number:0.2888763958456214
# random_number:0.2427727135873422
# random_number:0.5748585982874665
# random_number:0.5708686023044492
# random_number:0.4388986724436871
# random_number:0.4404553529945209
# random_number:0.5643682909017911
# random_number:0.8760037514672686
# random_number:0.9371978222616639
# random_number:0.7104247470559164
# random_number:0.0006213080056837184
# random_number:0.11258907732180201
# random_number:0.18087432524356417
# random_number:0.40909257783042174
# random_number:0.10145514603698635
# random_number:0.8833535497558436
# random_number:0.431568884524018
# random_number:0.48448119585321014
# random_number:0.799342882086175
# random_number:0.2041548849174627
# random_number:0.6453492388541305
# random_number:0.0605794095503962
# random_number:0.4205179055248198
# random_number:0.532723703996256
# random_number:0.7307480468819059
# random_number:0.7931289593679615
# random_number:0.11752400646468086
# random_number:0.3037542521465173
# random_number:0.03566187356969097
# random_number:0.4702813535613455
# random_number:0.5705875608359782
# random_number:0.3323102361250476
# random_number:0.8264379822397689
# random_number:0.37961677649462044
# random_number:0.06356875856709421
# random_number:0.4041153042312995
# random_number:0.7148042414847247
# random_number:0.6166241901884001
# random_number:0.9620487757097733
# random_number:0.9241847307365982
# random_number:0.9515004153439209
# random_number:0.6886737509862998
# random_number:0.6628674263332347
# random_number:0.33464182893847283
# random_number:0.5718666133437347
# random_number:0.09564267014241934
# random_number:0.35686216126413417
# random_number:0.4825854604398985
# random_number:0.9297345557119989
# random_number:0.9693430616849733
# random_number:0.4969001289680489
# random_number:0.09758355390599327
# random_number:0.39941972035377926
# random_number:0.9927608858658807
# random_number:0.343239590966371
# random_number:0.6066656797827824
# random_number:0.835187125850326
# random_number:0.777258300049748
# random_number:0.19552624939270613
# random_number:0.7557954709791438
# random_number:0.061939447570250716
# random_number:0.4920562096295361
# random_number:0.646956684583679
# random_number:0.5032349025817627
# random_number:0.6962790672048905
# random_number:0.8115807281382316
# random_number:0.6008832906901408
# random_number:0.4616844895537878
# random_number:0.15882358080607817
# random_number:0.4063150748516532
# random_number:0.9971352591811338
# random_number:0.7526679230114014
# random_number:0.019400608902880312
# random_number:0.3208069978678584
# random_number:0.8325279771047995
# random_number:0.9676374651016633
# random_number:0.8406935088794999
# random_number:0.4491099889638682
# random_number:0.788003049644146
# random_number:0.2450660878899643
# random_number:0.6514455464621391
# random_number:0.8146555106485526
# random_number:0.27042868567406597
# random_number:0.32621296211285655
# random_number:0.11341656787845245
# random_number:0.38997489161068877
# random_number:0.20442725768854875
# random_number:0.389849799727754
# random_number:0.08689758176434603
# random_number:0.46605428867995646
# random_number:0.7732017918334386
# random_number:0.26673598622375705
# random_number:0.973325542965143
# random_number:0.7666151626645051
# random_number:0.26295103528989916
# random_number:0.16557992318949755
# random_number:0.6137337040807211
# random_number:0.5928515343660957
# random_number:0.17057517621287166
# random_number:0.5100794108592323
# random_number:0.5868793014259204
# random_number:0.22914711111871977
# random_number:0.6252378162944695
# random_number:0.3568530298728467
# random_number:0.8621708896258546
# random_number:0.8698818215392846
# random_number:0.31868089596700166
# random_number:0.7438177574179542
# random_number:0.20166286649856024
# random_number:0.3927926055312786
# random_number:0.15211127750391396
# random_number:0.5389387106212824
# random_number:0.2541098343474274
# random_number:0.21699031274684621
# random_number:0.0033883493857781444
# random_number:0.5783666474842738
# random_number:0.49506007322356305
# random_number:0.985122155123842
# random_number:0.023318613262536925
# random_number:0.05187636044178656
# random_number:0.19813122062526645
# random_number:0.6110691767109487
# random_number:0.7321533632691042
# random_number:0.1099627742938456
# random_number:0.49767027197656133
# random_number:0.21587065731235455
# random_number:0.22002068961350996
# random_number:0.9573352381796969
# random_number:0.9591314697391748
# random_number:0.05226850571405861
# random_number:0.9119985405842782
# random_number:0.82336999951839
# random_number:0.07857009833593986
# random_number:0.3191749697629348
# random_number:0.46274073588397835
# random_number:0.386090535856211
# random_number:0.03684864971064161
# random_number:0.24541750165609755
# random_number:0.05962032557773678
# random_number:0.9014826330747556
# random_number:0.2451363998875593
# random_number:0.43483311670782565
# random_number:0.050988686306582265
# random_number:0.2254102271839642
# random_number:0.8175651384236576
# random_number:0.8503365851994924
# random_number:0.10649160340037533
# random_number:0.716191759191248
# random_number:0.9285800683038664
# random_number:0.2535763879005236
# random_number:0.10172302353769425
# random_number:0.903516797583704
# random_number:0.04642452916468964
# random_number:0.7903285659222209
# random_number:0.9830803877346961
# random_number:0.9635922216075191
# random_number:0.3367128987853276
# random_number:0.16635139045717673
# random_number:0.6238145202525518
# random_number:0.6051431835903618
# random_number:0.7747965429392051
# random_number:0.17770031534577113
# random_number:0.5378375789735542
# random_number:0.48374771367892233
# random_number:0.22636872391194396
# random_number:0.09618249904468845
# random_number:0.844801861929133
# random_number:0.17225833413834746
# random_number:0.37383808000744323
# random_number:0.6014425445826579
# random_number:0.8102636468187292
# random_number:0.8320184009688776
# random_number:0.5451022391592182
# random_number:0.5438030878958482
# random_number:0.04738135404385846
# random_number:0.809123985132254
# random_number:0.8157707942781788
# random_number:0.8801652712516905
# random_number:0.07891958168592395
# random_number:0.8985499099159251
# random_number:0.7402471563110642
# random_number:0.5836117102984877
# random_number:0.7253942588650742
# random_number:0.7648474282610929
# random_number:0.6019164759661947
# random_number:0.7485389530182798
# random_number:0.9782314418497281
# random_number:0.11738916974492652
# random_number:0.3089184507775663
# random_number:0.7188366389304001
# random_number:0.9727327295859112
# random_number:0.18053414856611416
# random_number:0.46675007165608096
# random_number:0.4778431162055261
# random_number:0.5961079342414131
# random_number:0.0012148436535895923
# random_number:0.39371670391866864
# random_number:0.9209257031860866
# random_number:0.7954620630689834
# random_number:0.2603277778752404
# random_number:0.00839300440833246
# random_number:0.2883224654364006
# random_number:0.9091166341109373
# random_number:0.6739215043561452
# random_number:0.3507009411280071
# random_number:0.284053404539393
# random_number:0.5451950800798262
# random_number:0.39574320201165347
# random_number:0.9229909321880228
# random_number:0.8590822801968234
# random_number:0.5695987606956507
# random_number:0.508017582297716
# random_number:0.6951313316305172
# random_number:0.6128562633108173
# random_number:0.20568162087238462
# random_number:0.844354188338525
# random_number:0.12265160480654802
# random_number:0.17049595570717624
# random_number:0.008123005059422761
# random_number:0.645905961745096
# random_number:0.582575347479767
# random_number:0.4596746601262416
# random_number:0.9746134930977071
# random_number:0.12956312815886406
# random_number:0.7165189132513121
# random_number:0.6340744869421414
# random_number:0.570100216553888
# random_number:0.9311845938452182
# random_number:0.6421696328000956
# random_number:0.48455380177668916
